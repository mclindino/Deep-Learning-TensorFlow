# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sea
import matplotlib.pyplot as plt

# %% [markdown]
# # Celsius to Fahrenheit

# %%
temp_df = pd.read_csv('../datasets/Celsius-to-Fahrenheit.csv')
temp_df.reset_index(drop = True, inplace = True)
temp_df.head()
# Out:
#    Celsius  Fahrenheit
# 0      -50       -58.0
# 1      -40       -40.0
# 2      -30       -22.0
# 3      -20        -4.0
# 4      -10        14.0

# %%
sea.scatterplot(temp_df['Celsius'], temp_df['Fahrenheit']);

# %%
x_train = temp_df['Celsius']
y_train = temp_df['Fahrenheit']

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units = 1, input_shape = [1]))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(0.1), loss = 'mean_squared_error')

# %%
epochs_hist = model.fit(x_train, y_train, epochs = 1000)
# Out:
# Train on 30 samples
# Epoch 1/1000
# 30/30 [==============================] - 0s 5ms/sample - loss: 1080.6614
# Epoch 2/1000
# 30/30 [==============================] - 0s 40us/sample - loss: 1043.0829
# Epoch 3/1000
# 30/30 [==============================] - 0s 46us/sample - loss: 1016.0624
# Epoch 4/1000
# 30/30 [==============================] - 0s 38us/sample - loss: 999.1479
# Epoch 5/1000
# 30/30 [==============================] - 0s 33us/sample - loss: 990.8357
# Epoch 6/1000
# 30/30 [==============================] - 0s 33us/sample - loss: 988.2228
# Epoch 7/1000
# 30/30 [==============================] - 0s 63us/sample - loss: 987.5032
# Epoch 8/1000
# 30/30 [==============================] - 0s 61us/sample - loss: 985.4525
# Epoch 9/1000
# 30/30 [==============================] - 0s 88us/sample - loss: 980.5735
# Epoch 10/1000
# 30/30 [==============================] - 0s 46us/sample - loss: 972.9782
# Epoch 11/1000
# ...

# %%
plt.plot(epochs_hist.history['loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training loss')
plt.legend(['Training loss']);

# %% [markdown]
# # Ice cream sales

# %%
sales_df = pd.read_csv('../datasets/salesdata.csv')
sales_df.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
sea.scatterplot(sales_df['Temperature'], sales_df['Revenue']);

# %%
x_train = sales_df['Temperature']
y_train = sales_df['Revenue']

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units = 1, input_shape = [1]))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(0.1), loss = 'mean_squared_error')

# %%
history = model.fit(x_train, y_train, epochs = 1000)
# Out:
# Train on 500 samples
# Epoch 1/1000
# 500/500 [==============================] - 0s 450us/sample - loss: 275223.0220
# Epoch 2/1000
# 500/500 [==============================] - 0s 67us/sample - loss: 235818.1130
# Epoch 3/1000
# 500/500 [==============================] - 0s 74us/sample - loss: 201043.3169
# Epoch 4/1000
# 500/500 [==============================] - 0s 71us/sample - loss: 169788.9480
# Epoch 5/1000
# 500/500 [==============================] - 0s 74us/sample - loss: 142405.3972
# Epoch 6/1000
# 500/500 [==============================] - 0s 75us/sample - loss: 118766.6826
# Epoch 7/1000
# 500/500 [==============================] - 0s 64us/sample - loss: 98236.9249
# Epoch 8/1000
# 500/500 [==============================] - 0s 57us/sample - loss: 80683.7791
# Epoch 9/1000
# 500/500 [==============================] - 0s 78us/sample - loss: 65772.1455
# Epoch 10/1000
# 500/500 [==============================] - 0s 72us/sample - loss: 53253.4341
# Epoch 11/1000
# ...

# %%
plt.plot(history.history['loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training loss')
plt.legend(['Training loss']);

# %%
plt.scatter(sales_df['Temperature'], sales_df['Revenue'], color = 'grey')
plt.title('Revenue Generated vs. Temperature @Ice Cream Stand')
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.plot(sales_df['Temperature'], model.predict(sales_df['Temperature']), color = 'red');
